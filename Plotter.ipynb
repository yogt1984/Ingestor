# %%
# !ls -l
# Out:
# total 31864
# -rw-rw-r-- 1 onat onat    31974 Mär 12 17:40 Cargo.lock
# -rw-rw-r-- 1 onat onat      457 Mär 12 17:40 Cargo.toml
# -rw-rw-r-- 1 onat onat 32577601 Mär 12 18:05 ingested_888.json
# drwxrwxr-x 2 onat onat     4096 Mär 12 17:37 src
# drwxrwxr-x 3 onat onat     4096 Mär 12 17:41 target
# -rw-rw-r-- 1 onat onat       72 Mär 12 18:06 Untitled.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load JSON file into a DataFrame
file_path = "ingested_888.json"  # Replace with your actual JSON file path
df = pd.read_json(file_path)

# Display the first few rows
print(df.head())

# Visualize the number of non-null values per column
df.notnull().sum().plot(kind='bar', figsize=(10,5), title="Non-null Values per Column")
plt.xlabel("Columns")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
#                E            U  \
# 0  1741798554614  63972777980
# 1  1741798554714  63972778006
# 2  1741798554814  63972778089
# 3  1741798554914  63972778176
# 4  1741798555014  63972778218
#
#                                                    a  \
# 0  [[81933.97000000, 7.82260000], [81939.94000000...
# 1  [[81933.97000000, 7.59199000], [81933.99000000...
# 2  [[81933.97000000, 5.51887000], [81934.00000000...
# 3  [[81933.97000000, 4.77453000], [81934.12000000...
# 4  [[81933.97000000, 3.79654000], [81934.28000000...
#
#                                                    b            e  \
# 0  [[81933.96000000, 0.06303000], [81933.95000000...  depthUpdate
# 1  [[81933.96000000, 0.29443000], [81933.95000000...  depthUpdate
# 2  [[81933.96000000, 1.33053000], [81933.95000000...  depthUpdate
# 3  [[81933.96000000, 2.42843000], [81933.21000000...  depthUpdate
# 4  [[81931.69000000, 0.00000000], [81929.16000000...  depthUpdate
#
# ...

# %%
df.columns
# Out:
# Index(['E', 'U', 'a', 'b', 'e', 'features', 's', 'u'], dtype='object')

# %%
df.features[1123]['weighted_mid_price']
# Out:
# 82047.98955218545

# %%
# plot and check the consistencies.
